# %% [markdown]
# <div align="center">
#     <span style="font-size:30px">
#         <strong>
#             <!-- Python Symbol -->
#             <img
#                 src="https://cdn3.emoji.gg/emojis/1887_python.png"
#                 style="margin-bottom:-5px"
#                 width="30px"
#                 height="30px"
#             >
#             <!-- Título -->
#             Python for Geologists
#             <!-- Versión -->
#             <img
#                 src="https://img.shields.io/github/release/kevinalexandr19/python_for_geologists.svg?style=flat&label=&color=blue"
#                 style="margin-bottom:-2px"
#                 width="40px"
#             >
#         </strong>
#     </span>
#     <br>
#     <span>
#         <!-- Github del proyecto -->
#         <a href="https://github.com/kevinalexandr19/python_for_geologists" target="_blank">
#             <img src="https://img.shields.io/github/stars/kevinalexandr19/python_for_geologists.svg?style=social&label=Github Repo">
#         </a>
#         &nbsp;&nbsp;
#         <!-- Licencia -->
#         <img src="https://img.shields.io/github/license/kevinalexandr19/python_for_geologists.svg?color=forestgreen">
#         &nbsp;&nbsp;
#         <!-- Release date -->
#         <img src="https://img.shields.io/github/release-date/kevinalexandr19/python_for_geologists?color=gold">
#     </span>
#     <br>
#     <span>
#         <!-- Perfil de LinkedIn -->
#         <a target="_blank" href="https://www.linkedin.com/in/kevin-alexander-gomez/">
#             <img src="https://img.shields.io/badge/-Kevin Alexander Gomez-0072B1">
#         </a>
#         &nbsp;&nbsp;
#         <!-- Perfil de Github -->
#         <a target="_blank" href="https://github.com/kevinalexandr19">
#             <img src="https://img.shields.io/github/followers/kevinalexandr19.svg?style=social&label=kevinalexandr19&maxAge=2592000">
#         </a>
#     </span>
#     <br>
# </div>
#
# ***

# %% [markdown]
# ## <span style="color:lightgreen">Welcome to the Python for Geologists project !!! </span> 🌎📚
#
# This academic project was created to <span style="color:lightgreen">make learning Python accessible</span> for students and professionals in Geology and related disciplines.
#
# Beyond teaching Python, this resource aims to foster <span style="color:lightgreen">algorithmic thinking</span> as a practical tool for solving real geological problems.
#
# This version of the repository is built on [JupyterLite](https://jupyterlite.readthedocs.io/en/stable/), enabling Python code to run directly in the browser with no prior installation, making the learning experience seamless for geoscience students.

# %% [markdown]
# <span style="color:gold; font-size:20px">**Topics**</span>
# ***
#
# - [Variables](#part-1)
# - [Showing results in Python](#part-2)
# - [Computational logic](#part-3)
# - [Data structures](#part-4)
# - [Task automation](#part-5)
# - [Object-oriented programming](#part-6)
# - [Standard Python libraries](#part-7)
#
# ***

# %% [markdown]
# <a id="part-1"></a>

# %% [markdown]
# ### <span style="color:lightgreen">**Variables**</span>
# ***
#
# - **Variable and function names** <br>
# They must start with a letter or an underscore and may contain letters, numbers, and underscores. <br>
# By convention, `lowercase_names_with_underscores` are used for variables and functions, and `CamelCaseNames` are used for classes.
#
# - **Strings** <br>
# You can use single quotes `''` or double quotes `""`, but it is important to be consistent throughout the project. <br>
# For multi-line strings, use triple quotes: `'''` or `"""`.
#
# - **Comments** <br>
# Comments in Python start with the `#` symbol. <br>
# It is good practice to comment your code, but avoid obvious or redundant comments.

# %% [markdown]
# <a id="part-2"></a>

# %% [markdown]
# ### <span style="color:lightgreen">**Showing results in Python**</span>
# ***
#
# - **Parentheses for clarity** <br>
# Although they are not always required, using parentheses can make complex expressions easier to read.
#
# - **f-strings** <br>
# f-strings allow variables to be embedded directly inside a string, improving efficiency, flexibility, and readability of the code.
#
# - **Line breaks** <br>
# You can use `\n` inside a string to indicate a line break.
#
# <br>

# %% [markdown]
# #### **1. Mineral data**
#
# Create two variables: one for the name of a mineral and another for its hardness on the Mohs scale. <br>
# Use f-strings to print a sentence that says: `The mineral {name} has a hardness of {hardness} on the Mohs scale.`

# %% [markdown]
# #### **2. Rock age**
#
# Define one variable for the name of a rock and another for its age in millions of years. <br>
# Use f-strings to print a message that says: `The rock {name} has an age of {age} million years.`

# %% [markdown]
# #### **3. Sample record**
#
# You are asked to record the following information for a rock sample using variables:
#
# - Rock name
# - Rock type (sedimentary, igneous, metamorphic)
# - Sample weight in kilograms
#
# Use f-strings to print a sample record containing this information.

# %% [markdown]
# #### **4. Unit conversion**
#
# Write a program that converts the density of a rock from grams per cubic centimeter (g/cm³) to kilograms per cubic meter (kg/m³).
# The program should ask the user to enter the density in g/cm³ and then print the converted density in kg/m³ using f-strings.

# %% [markdown]
# #### **5. Volcano location**
#
# Define variables for the name of a volcano, its height in meters, and its geographic coordinates (latitude and longitude).
# Then, use f-strings to print a detailed description of the volcano’s location.

# %% [markdown]
# #### **6. Deposit information**
#
# Define three variables:
# - One for the name of a deposit.
# - Another for the predominant mineral type.
# - And a third for the estimated amount of reserves in tonnes.
#
# Use f-strings to print a complete description of the deposit.

# %% [markdown]
# #### **7. Depth calculation**
#
# Given an exploration well, record its starting point and its ending point in meters.
# Calculate the total depth of the well and use f-strings to print a summary containing all this information.

# %% [markdown]
# #### **8. Mine production report**
#
# A gold (Au) mine obtained the following production results for a given six-month period:
#
# | Month | Au (ounces) |
# | --- | --- |
# | January | 80 |
# | February | 105 |
# | March | 45 |
# | April | 80 |
# | May | 75 |
# | June | 125 |
#
# To generate a general production report, you are asked to:
# - Calculate the total number of Au ounces produced during the six-month period and assign it to the variable `total`.
# - The monthly operating cost of the mine is 40,000 dollars. Assign it to the variable `operating_cost`.
# - The price of one ounce of Au is 1,000 dollars. Assign it to the variable `price`.
# - Using these three variables, calculate the six-month profit of the mine and assign it to the variable `profit`.
# - Display the final result using the `print` function, following this format: <br>
# `"During the six-month period, the mine produced ___ ounces of Au with a total profit of ___ dollars"`

# %% [markdown]
# #### **9. Sample information**
#
# Write a program that asks the user for the name of a rock sample and the SiO₂ percentage of that sample. <br>
# Then, use f-strings to print a summary in the following format: `The sample {name} contains {percentage}% SiO₂.`

# %% [markdown]
# #### **10. Geological risk in a building**
#
# What is the probability that a building will experience an earthquake of magnitude 7.0, considering that its design life is 100 years and the earthquake return period is 500 years? Use the following formula to calculate the probability of exceedance:
#
# <center>
#     $ \Large p = 1 - (1 - \frac{1}{T})^{t}$
# </center>
#
# Where:
#
# - $p$ : probability of exceedance
# - $t$ : design life of the structure
# - $T$ : return period

# %% [markdown]
# #### **11. Earthquake report**
#
# Define variables to record the date, time, magnitude, depth, and location of an earthquake.
# Then, using f-strings, create a function that, when called, generates a detailed report of the seismic event.

# %% [markdown]
# #### **12. Seismic wave propagation**
#
# An earthquake was detected at an observation station. <br>
# The arrival of the P waves occurred at 10h 23m 37s, while the S waves were recorded at 10h 24m 22s. <br>
# The estimated seismic wave velocities were: $V_{P} = 7.2 \, \text{km/s}$ and $V_{S} = 4.15 \, \text{km/s}$.
#
# Using the following seismic wave propagation model, calculate the distance to the earthquake epicenter:
#
# <center>
#     $ \Large d = \frac{T_{S} - T_{P}}{\frac{1}{V_{S}} - \frac{1}{V_{P}}} $
# </center>
#
# Where:
# - $d$: distance to the earthquake epicenter
# - $V_{P}$, $V_{S}$: velocities of P and S seismic waves
# - $T_{P}$, $T_{S}$: arrival times of the P and S seismic waves

# %% [markdown]
# <a id="part-3"></a>

# %% [markdown]
# ### <span style="color:lightgreen">**Computational logic**</span>
# ***
#
# - **Control structures** <br>
# A colon `:` is always used at the end of the line that introduces a new control structure (for example, `if`, `for`, `while`, `def`, `class`). <br>
# If the structure has no content, you can use the reserved keyword `pass` to indicate an empty block.
#
# - **Indentation** <br>
# Python uses indentation to define code blocks (unlike other languages that use curly braces `{}`). <br>
#     <span style="color:gold">Incorrect indentation can cause errors.</span> <br>
# It is recommended to use 4 spaces for each indentation level, although tabs can also be used. <br>
# It is important to be consistent throughout the code.
#
# <br>

# %% [markdown]
# #### **13. Volcanic risk**
#
# Write a program that, based on the recent activity of a volcano (number of eruptions in the last year) and its proximity to populated areas (in kilometers), determines the level of risk using the following criteria:
#
# - `High Risk`: more than 10 eruptions in the year and a proximity of up to 10 km.
# - `Moderate Risk`: more than 5 eruptions in the year and a proximity of up to 20 km.
# - `Low Risk`: up to 5 eruptions in the year or a proximity of at least 20 km.

# %% [markdown]
# #### **14. Igneous rock classification**
#
# To classify an igneous rock according to its silica content (SiO$_{2}$), the following criteria are commonly used:
#
# - **Ultramafic igneous rocks**: contain less than 45% SiO$_{2}$.
# - **Mafic igneous rocks**: contain between 45% and 52% SiO$_{2}$.
# - **Intermediate igneous rocks**: contain between 52% and 66% SiO$_{2}$.
# - **Felsic igneous rocks**: contain more than 66% SiO$_{2}$.
#
# Using conditional statements, create a program that asks the user to enter a numerical silica value and determines the classification of the igneous rock based on this content.

# %% [markdown]
# #### **15. Petroleum exploration**
#
# An oil reservoir is considered viable if its pressure is greater than 20 MPa and its temperature is lower than 150°C.
# Create a program that, given these two variables, determines whether the reservoir is viable for exploration.

# %% [markdown]
# #### **16. Soil erosion risk**
#
# Develop an algorithm to determine whether an area is prone to erosion based on:
# - Annual precipitation (mm): total rainfall in one year.
# - Vegetation: can be `abundant`, `moderate`, or `scarce`.
#
# The area is `prone` to erosion if precipitation exceeds 1000 mm and vegetation is `scarce`. In any other case, the area is `not prone` to erosion. <br>
# The result should be a message indicating whether the area is `prone` or `not prone` to erosion.

# %% [markdown]
# #### **17. Aquifer assessment**
#
# Develop a program to determine whether an aquifer is suitable for human consumption based on:
#
# - Salt concentration (%): a numeric value representing the percentage of salts in the aquifer.
# - Contaminants: a categorical response (`Yes` or `No`) indicating the presence of toxic contaminants.
#
# An aquifer is considered suitable for consumption if the salt concentration is less than 5% and it has no toxic contaminants.
# The program must determine and display whether the aquifer water is `suitable` or `not suitable` for consumption.

# %% [markdown]
# #### **18. Determining whether a deposit is profitable to mine**
#
# A deposit is profitable if it contains more than 5,000 tonnes of ore and the ore grade is greater than 5%.
# Write a program that, given these two variables, determines whether it is profitable to mine the deposit.

# %% [markdown]
# #### **19. Reserve classification**
#
# One of the blocks in a deposit has assigned values of density (in g/cm³) and gold grade (in g/t).
# Determine whether the block belongs to a `high-quality` reserve (grade greater than 1.0 g/t and density greater than 3.0 g/cm³) or a `low-quality` reserve (grade less than 1.0 g/t or density less than 3.0 g/cm³).

# %% [markdown]
# #### **20. Detailed deposit analysis**
#
# A deposit has several properties: tonnage, grade (in %), depth (in meters), and distance to the market (in kilometers).
# Write a program that determines:
#
# - Whether the deposit is profitable to mine (more than 5,000 tonnes and grade greater than 5%).
# - Whether it is easily accessible (depth less than 200 meters).
# - Whether it is close to the market (distance less than 50 kilometers).
#
# Based on these conditions, the program must determine whether the deposit is:
# - `ideal` (meets all three conditions),
# - `average` (meets two conditions), or
# - `not recommended` (meets one or none of the conditions).

# %% [markdown]
# <a id="part-4"></a>

# %% [markdown]
# ### <span style="color:lightgreen">**Data structures**</span>
# ***
#
# - **Spacing** <br>
# Use spaces around operators and after commas to improve readability. <br>
# Avoid extra spaces at the beginning or end of lists/tuples: use `[a, b, c]` instead of `[ a, b, c ]`.

# %% [markdown]
# #### **21. Rock types**
#
# Create a list with five common rock names: granite, gneiss, sandstone, andesite, and basalt.
# Then, display the second and fourth elements in the list using `print`.

# %% [markdown]
# #### **22. Is it a metallic mineral?**
#
# Develop a program that determines whether a mineral entered by the user is metallic or not:
#
# - Define a list with the following metallic minerals: pyrite, chalcopyrite, sphalerite, galena.
# - Ask the user to enter the name of a mineral.
# - Use conditional statements to check whether the entered mineral is in the list of metallic minerals.
# - Display a message using `print` indicating whether the entered mineral is metallic or not.

# %% [markdown]
# #### **23. Rock collection**
#
# Create a list of rocks with the following initial elements: basalt, andesite, dacite, and rhyolite.
# Develop a program that allows the user to perform different operations on the list (using `input`).
# The program should ask the user to choose one of the following options:
#
# 1. Display the total number of elements in the list.
# 2. Display all elements in the list.
# 3. Add a new rock to the list.

# %% [markdown]
# #### **24. Density average calculation**
#
# Develop a program that allows the user to enter the densities of five different rocks (in g/cm³).
# The program should request the densities through five separate inputs, display the final list using `print`, calculate the average density of all samples, and display a message using f-strings to indicate the result.

# %% [markdown]
# #### **25. Basic geographic data**
#
# Define a tuple containing the latitude and longitude of an important deposit. Then, display both values using `print`.

# %% [markdown]
# #### **26. Mohs scale**
#
# Define a dictionary that associates some minerals with their hardness on the Mohs scale. For example:
#
# ```python
# {"talc": 1, "gypsum": 2}
# ```
#
# Display the hardness of one of the minerals using f-strings.

# %% [markdown]
# #### 27. Dictionary keys
#
# A dictionary contains information about several geological properties of a sample. <br>
# Check whether the key `rock_type` is present in the dictionary.

# %%
muestra_geologica = {
    "name": "Sample A",
    "latitude": 12.0,
    "longitude": -20.0,
    "location": "Lima, Peru",
    "depth": 150,
    "rock_type": "igneous",
    "mineral_content": "quartz"
}

# %% [markdown]
# #### **28. Rock sample mineralogy (Part 1)**
#
# A granodiorite sample has the following mineralogical composition: quartz $(48\%)$, plagioclase $(27\%)$, feldspar $(11\%)$, biotite $(8\%)$, pyrite $(6\%)$. <br>
# Create a Python dictionary that stores the mineralogy of the sample. The percentages must be represented as fractions (for example, 25% will be equal to 0.25).

# %% [markdown]
# #### **29. Rock catalog**
#
# You have a rock collection consisting of a list that contains several dictionaries. Each dictionary represents a rock with properties such as `name`, `type` (sedimentary, igneous, metamorphic), and `location` (the country where it is commonly found). <br>
# Using this list, display the properties of the first and last rock in the collection using `print`.

# %%
# List of dictionaries
collection = [
    {"name": "andesite", "type": "igneous", "location": "Peru"},
    {"name": "sandstone", "type": "sedimentary", "location": "Chile"},
    {"name": "slate", "type": "metamorphic", "location": "Ecuador"}
]

# %% [markdown]
# #### **30. Alphabetical ordering of a mineral collection**
#
# Develop a program that sorts a geological data dictionary based on its keys. <br>
# The dictionary keys will be mineral names, and the associated values will be their hardness on the Mohs scale. <br>
# The program must sort the dictionary in lexicographical (alphabetical) order by keys and display the sorted dictionary.

# %%
# Dictionary of minerals
hardness = {
    "quartz": 7,
    "feldspar": 6,
    "calcite": 3,
    "mica": 2.5,
    "diamond": 10,
    "pyrite": 6
}

# %% [markdown]
# #### **31. Deposits around the world**
#
# You have a list of tuples, where each tuple represents a metallic mineral deposit and contains the deposit `name`, `country`", and extracted `commodity`. Display the details of two deposits in the list using `print` and f-strings.

# %%
# List of tuples
deposits = [
    # Name, country, commodity
    ("Antamina", "Peru", "Cu"),
    ("Witwatersrand", "South Africa", "Au"),
    ("Olympic Dam", "Australia", "Cu"),
    ("Escondida", "Chile", "Cu")
]

# %% [markdown]
# #### **32. Deposit database**
#
# You have a list of tuples. Each tuple represents a deposit with data such as deposit `mame`, predominant `mineral` type, estimated mineral `reserves` (in tonnes), and `country`. <br>
# Using this data structure, display the information for the deposit with the largest mineral reserves, <span style="color:#43c6ac">without using concepts such as loops or functions</span>.

# %%
# Database
deposits = [
    # Name, mineral, reserves (tonnes), country
    ("Antamina", "chalcopyrite", 5e8, "Peru"),
    ("Las Bambas", "bornite", 6e8, "Peru"),
    ("Escondida", "chalcopyrite", 12e8, "Chile"),
    ("San Vicente", "sphalerite", 10e8, "Peru"),
    ("Grasberg", "bornite", 9e8, "Indonesia"),
    ("Olympic Dam", "chalcopyrite", 8e8, "Australia")
]

# %% [markdown]
# <a id="part-5"></a>

# %% [markdown]
# ### <span style="color:lightgreen">**Task automation**</span>
# ***

# %% [markdown]
# #### **33. Maximum hardness**
#
# Design a function called `get_maximum_hardness` that, given a list containing the hardness values of several minerals (on the Mohs scale), returns a message indicating the maximum hardness found.

# %%
# Hardness list
harndess = [2.5, 2.0, 2.5, 5.0, 4.0, 6.0, 4.0, 7.0, 8.0, 4.0, 3.0, 2.5, 4.0, 3.0]

# %% [markdown]
# #### **34. Grade average**
#
# Create a function called `average` that receives a list containing the grades of different mineral samples and returns the average of those grades.

# %%
# Ore grade list
grades = [2, 2.1, 3, 0.5, 0.6, 1.2, 1.5, 4.5, 3.0, 2.6, 1.6]

# %% [markdown]
# #### **35. Sum of depths**
#
# Write a function called `sum_depths` that receives a list of depths from different wells and returns the total sum of all depths.

# %%
# Depth list
depths = [200, 300, 150, 500, 250]

# %% [markdown]
# #### **36. Determine rock type**
#
# Develop a program that determines the rock type based on its mineral composition. The program should ask the user to enter the minerals present in the rock one by one, and then classify the rock according to the following rules:
#
# - If the rock contains quartz and feldspar, but not mica, the program should print that it is a type of granite.
# - If the rock contains mica, but not quartz, the program should print that it is a mica schist.
# - If the rock does not meet any of the rules above, the program should print that the rock cannot be classified.

# %% [markdown]
# #### **37. Average thickness**
#
# Develop a function called `average_thickness` that, given a list of thickness values from a stratigraphic sequence, returns a message indicating the average thickness of the sequence.

# %%
# Thickness list
thickness = [20, 30, 15, 50, 25, 40, 21, 17]

# %% [markdown]
# #### **38. Rock sample mineralogy (Part 2)**
#
# <span style="color:#43c6ac">Using the dictionary obtained in Exercise 28</span>, display the name and percentage of each mineral using a definite loop. <br>
# Use the following format: `Abundance of ____ in the sample: _____ %`

# %% [markdown]
# #### **39. Mineral reserves**
#
# You have a dictionary where the keys are country names and the values are lists of tuples representing mining deposits in that country. Each tuple contains the following information: `deposit name`, `extracted metal`, and `estimated tonnage`.
#
# Develop a program that finds the deposit with the largest amount of mineral reserves and displays its name and the country where it is located.

# %%
# Dictionary of deposits
deposits = {
    "Peru" : [
        # Name, extracted metal, estimated tonnage
        ("Antamina", "copper", 1_500_000),
        ("Quellaveco", "copper", 500_000),
        ("Yanacocha", "gold", 1_000_000),
        ("Toromocho", "copper", 2_500_000)       
    ],
    "Chile": [
        # Name, extracted metal, estimated tonnage
        ("Chuquicamata", "copper", 5_000_000),
        ("Escondida", "copper", 6_000_000),
        ("El Teniente", "copper", 4_000_000)
    ]
}

# %% [markdown]
# #### **40. Mineral list (Part 1)**
#
# Implement a function called `display_minerals` that takes a list of minerals as an argument and, using a loop, prints each mineral in the list.

# %%
# List of minerals
minerals = ["quartz", "galena", "chalcopyrite", "pyrite", "pyroxene", "halite"]

# %% [markdown]
# #### **41. Mineral list (Part 2)**
#
# Modify the function `display_minerals` implemented in Exercise 40 so that it prints each mineral in the list, <span style="color:#43c6ac">sorted alphabetically</span>.

# %%
# List of minerals
minerals = ["quartz", "galena", "chalcopyrite", "pyrite", "pyroxene", "halite"]

# %% [markdown]
# #### **42. Hardest mineral**
#
# You have a list of tuples where each tuple contains the name of a mineral and its hardness on the Mohs scale. <br>
# Design a function called `hardest_mineral` that iterates over this list and returns the name of the mineral with the highest hardness. <br>
# Then, using `print`, display the name of the hardest mineral found.

# %%
# List of minerals
minerals = [("quartz", 7), ("galena", 2.5), ("chalcopyrite", 4), ("pyrite", 6), ("pyroxene", 6.5), ("halite", 2)]

# %% [markdown]
# #### **43. Rock count**
#
# Create a function called `count_rocks` that receives a list of rocks and returns how many times a specific rock (for example, `granite`) appears in the list.

# %%
# List of rocks
rocks = ["andesite", "granite", "andesite", "andesite", "sandstone", "basalt",
         "andesite", "granite", "basalt", "shale", "andesite", "granite"]

# %% [markdown]
# #### **44. Rock classification**
#
# You have a list containing rock names. Develop two functions:
#
# - `classify_rock`: this function should receive the name of a rock and return its type (`sedimentary`, `igneous`, or `metamorphic`).
# - `count_rocks_by_type`: this function should receive the list of rock names and use `classify_rock` to classify each rock. <br>
#   It should then count how many rocks belong to each type and return a dictionary with these counts.
#
# The resulting dictionary must contain the number of rocks classified by type.

# %%
# List of rocks
rocks = ["sandstone", "granite", "basalt", "granite", "basalto", "gneiss",
         "schist", "schist", "sandstone", "limestone", "granite", "andesite",
         "basalt", "slate", "basalt", "granite", "sandstone", "limestone"]

# %% [markdown]
# #### **45. Target minerals**
#
# Write a function called `search_minerals` that receives a list of minerals found in an area and a list of target minerals. <br>
# The function should return a new list containing the minerals from the area that are present in the list of target minerals.

# %%
# Lists of minerals
minerals_found = ["quartz", "pyrite", "chalcopyrite", "sphalerite", "galena", "calcite",
                  "feldspar", "pyroxene", "jarosite", "hematite", "alunite"]
minerals_target = ["chalcopyrite", "sphalerite", "alunite", "electrum"]

# %% [markdown]
# #### **46. Profitable deposits**
#
# You have a list of deposits (represented as dictionaries with properties such as `tonnes` and `grade`).
# Develop a function called `evaluate_deposits` that receives this list and returns a new list containing only the deposits that have more than 5,000 tonnes and a grade greater than 5%.

# %%
# List of deposits
deposits = [
    {"name": "Antamina", "tonnage": 10_000, "grade": 6},
    {"name": "San Vicente", "tonnage": 6_000, "grade": 4},
    {"name": "Cerro Verde", "tonnage": 15_000, "grade": 7},
    {"name": "Las Bambas", "tonnage": 8_000, "grade": 5.5},
    {"name": "Yanacocha", "tonnage": 5_000, "grade": 6},
    {"name": "Collahuasi", "tonnage": 12_000, "grade": 4.5},
    {"name": "Grasberg", "tonnage": 11_000, "grade": 5.2},
    {"name": "Codea", "tonnage": 4_000, "grade": 3},
    {"name": "Oyu Tolgoi", "tonnage": 7_000, "grade": 6.5},
    {"name": "Escondida", "tonnage": 20_000, "grade": 8}
]

# %% [markdown]
# #### **47. Mineral comparison**
#
# You have two dictionaries representing minerals, each with the following properties: `name`, `hardness`, and `melting_point` (melting point in degrees Celsius).
#
# Develop a function called `compare_minerals` that receives these two mineral dictionaries and compares their properties. The function must:
# - Compare the hardness of the two minerals and indicate which one is harder, or whether they have the same hardness.
# - Compare the melting points of the two minerals and indicate which one has a higher melting point, or whether they have the same melting point.

# %%
# Minerals to compare
pyrite = {"name": "pyrite", "hardness": 6, "melting_point": 1000}
quartz = {"name": "quartz", "hardness": 7, "melting_point": 700}

# %% [markdown]
# #### **48. Percentage normalization for petrographic classification (Part 1)**
#
# Create a function named `streckeisen` with the following characteristics:
# - The function must take a **dictionary** as its input parameter.
# - The function must extract the percentages of `quartz`, `feldspar`, and `plagioclase` from the dictionary and normalize them.
# - The function must return a dictionary containing only these three minerals and their normalized percentages.
#
# Use the following dictionary to display the final result.

# %%
# Dictionary
sample = {"quartz": 0.48, "plagioclase": 0.27, "feldspar": 0.11, "biotite": 0.08, "pyrite": 0.06}

# %% [markdown]
# #### **49. Percentage normalization for petrographic classification (Part 2)**
#
# Use the `streckeisen` function <span style="color:#43c6ac">developed in Exercise 48</span> to normalize the rock sample stored in the following dictionary:
# > Note: If the function does not evaluate the sample correctly or raises an error, you must modify the function until it works for this case.

# %%
# Dictionary
sample = {"quartz": 0.41, "plagioclase": 0.25, "amphiboles": 0.17, "biotite": 0.12, "pyrite": 0.05}

# %% [markdown]
# #### **50. Rock classification by period**
#
# Develop a function that receives a list of rocks (represented as dictionaries with properties such as `name`, `age`, and `geological_period`). <br>
# The function must classify and return these rocks in separate lists according to their geological period (for example, Cretaceous, Jurassic, etc.).

# %%
# List of dictionaries
rocks = [
    # name, age, geological_period
    {"name": "andesite", "age": 200, "geological_period": "Triasic"},
    {"name": "granite", "age": 210, "geological_period": "Triasic"},
    {"name": "sandstone", "age": 240, "geological_period": "Triasic"},
    {"name": "granite", "age": 110, "geological_period": "Jurassic"},
    {"name": "andesite", "age": 100, "geological_period": "Jurassic"},
    {"name": "basalt", "age": 115, "geological_period": "Jurassic"},
    {"name": "slate", "age": 70, "geological_period": "Cretaceous"},
    {"name": "shale", "age": 85, "geological_period": "Cretaceous"},
]

# %% [markdown]
# #### **51. Terrestrial geothermal gradient model (Part 1)**
#
# Below a certain depth beneath the Earth’s surface, the internal temperature of the Earth varies according to the following model:
#
# - The average surface temperature is 25°C.
# - For the first 100 km of depth, the temperature increases linearly with a gradient of 15°C/km.
# - Beyond 100 km (and up to a maximum of 6,360 km), the temperature increases according to the following quadratic expression: <br>
# $ T(z) = -6\times10^{-5}\space z^{2} + 1.05\space z + 1395.6 $
#
# Develop a function named `temperature` that represents this geothermal gradient model:
#
# - The function must take the depth `z` as a parameter and return the following sentence: <br>
#   `At a depth of z km, the internal temperature of the Earth is T °C`. <br>
# - If the depth value is negative or greater than 6,360 km, the function must return the following sentence: <br>
#   `Depth value z is incorrect`.
# - Finally, evaluate the function for the following depth values: −100, 0, 50, 100, 2000, and 6400 km.

# %%
# Function
def temperature(z):
    # Write the code here
    pass

# %%
# Display the result for different values of z
for z in [-100, 0, 50, 100, 2000, 6400]:
    temperature(z)

# %% [markdown]
# #### **52. Extraction optimization**
#
# You have a 4×4 matrix that represents a mining deposit, where each cell contains a quantity of mineral in tonnes.
# Develop a function called `optimize_extraction` that receives this matrix and a specific number of blocks to extract. The function must return a list containing the selected cells and their corresponding mineral quantities, maximizing the total amount extracted.
#
# The function must:
# - Receive a `matrix` that represents the deposit.
# - Receive an integer `n_blocks` indicating the number of blocks to extract.
# - Identify and extract the cells with the highest mineral quantities.
# - Return a list with the coordinates of the extracted cells and their corresponding mineral quantities.

# %%
# Function
def optimize_extraction(matrix, n_blocks):
    # Write the code here
    pass

# %%
# Matriz de 4x4
deposit = [[100,  50,  60,  80],
           [110,  70,  80, 100],
           [ 70,  50,  30,   5],
           [100,  80,  40,  10]]

# %% [markdown]
# <a id="part-6"></a>

# %% [markdown]
# ### <span style="color:lightgreen">**Object-Oriented Programming**</span>
# ***
#
# - **Errors and exceptions** <br>
# It is important to know how to read and understand error messages. <br>
# This will help us troubleshoot and solve problems effectively.
#
# - **Consistency** <br>
# The most important aspect of writing code is being consistent. <br>
# If you choose to follow a particular convention or style, apply it uniformly throughout the entire project.

# %% [markdown]
# #### **53. Rock class**
#
# Create a class called `Rock` with attributes for `name` and `type` (such as sedimentary, igneous, or metamorphic). <br>
# Instantiate an object of this class and display its attributes using `print`.

# %% [markdown]
# #### **54. Fossil class**
#
# Develop a class called `Fossil` with attributes for `name`, `era` (such as Mesozoic, Paleozoic, etc.), and `age` (in millions of years). <br>
# Instantiate an object of this class and display its attributes using `print`.

# %% [markdown]
# #### **55. Earthquake class**
#
# Develop a class called `Earthquake` with attributes for `magnitude`, `epicenter`, and `date`.
# This class must include a method called `evaluate_magnitude` that determines whether the earthquake was `major` (magnitude greater than 7) or `minor`.

# %% [markdown]
# #### **56. Geochemical composition of a rock**
#
# You are asked to calculate the geochemical composition of a rock sample by following these steps:
#
# - Implement a class called `Rock`. This class must take as an argument a dictionary representing the mineralogical composition of the rock, with the following format:
#     ```python
#     # Example dictionary
#     minerals = {"quartz": 0.50, "feldspar": 0.20, "plagioclase": 0.30, "ferromagnesian": 0.00}
#     ```
# - The class must include a method called `get_oxides` that converts mineral percentages into oxide percentages using the following compositions:
#     - Quartz: $SiO_{2}$ (100%)
#     - Feldspars: $SiO_{2}$ (48%), $Al_{2}O_{3}$ (27%), $K_{2}O$ (25%)
#     - Plagioclase: $SiO_{2}$ (47%), $Al_{2}O_{3}$ (33%), $CaO$ (10%), $Na_{2}O$ (10%)
#     - Ferromagnesians: $SiO_{2}$ (40%), $Al_{2}O_{3}$ (5%), $CaO$ (10%), $FeOT$ (20%), $MgO$ (25%)
# - Store the result of the decomposition in an attribute called `oxides`, using a dictionary with the following format:
#     ```python
#     # Example result
#     oxides = {"SiO2": 0.60, "Al2O3": 0.15, "CaO": 0.05, "Na2O": 0.05, "K2O": 0.05, "FeOT": 0.05, "MgO": 0.05}
#     ```
# - Instantiate the `Rock` class to calculate the geochemical composition of a **diorite** sample with the following mineralogical composition: <br>
#   Quartz (25%), feldspars (10%), plagioclase (35%), ferromagnesian minerals (30%).
# - Finally, display both the mineralogical and geochemical compositions of the sample using `print` and f-strings.

# %%
# Diorite sample
diorite = {"quartz": 0.25, "feldspar": 0.1, "plagioclase": 0.35, "ferromagnesians": 0.3}

# %% [markdown]
# #### **57. Deposit class**
#
# Create a class called `Deposit` with attributes for `name`, `location`, and `quantity` (in tonnes).
# This class must include a method that determines whether the deposit is `large` (more than 10,000 tonnes) or `small`.

# %% [markdown]
# #### **58. Volcanoes**
#
# Develop a class called `Volcano` with attributes for `name`, `height` (in meters), and `status` (active, inactive, or extinct).
# The class must include:
#
# - A method called `evaluate_height` that determines whether the volcano is `high` (if it exceeds 4,000 meters) or `low` (otherwise).
# - A method called `summary` that summarizes the volcano’s attributes using `print` and f-strings, and includes the result of `evaluate_height`.

# %% [markdown]
# #### **59. Rock inheritance**
#
# Based on the `Rock` class <span style="color:#43c6ac">developed in Exercise 53</span>, create child classes for different rock types: `Igneous`, `Sedimentary`, and `Metamorphic`:
#
# - Each child class must include at least one additional attribute that distinguishes it from the others.
# - Additionally, implement a method called `evaluate_rock` in each child class that describes the rock’s attributes using `print` and f-strings.
# - Finally, create instances of the three child classes and use the `evaluate_rock` method to display the attributes of each instance.

# %% [markdown]
# #### **60. Simple mineral**
#
# Develop a class called `Mineral` with attributes for `name` and `hardness` (according to the Mohs scale).
# Create a method called `evaluate_hardness` that returns `hard` if the hardness is greater than 5, or `soft` otherwise.
# Finally, evaluate the mineral **quartz** with a hardness of 6.

# %% [markdown]
# #### **61. Rock composed of minerals**
#
# Based on the `Mineral` class <span style="color:#43c6ac">developed in Exercise 60</span>, implement a class called `Rock` that contains a list of instances of the `Mineral` class and an associated percentage attribute for each instance.
# The class must include a method called `evaluate_rock` that displays the name, hardness, and percentage of each mineral in the rock.
#
# Finally, instantiate the `Rock` class and display the results using the `evaluate_rock` method.

# %%
# List of minerals
minerals = [
    # Name, hardness (Mohs), percentage
    ("quartz", 7, 60),
    ("muscovite", 2, 10),
    ("orthoclase", 6, 30)
]

# %% [markdown]
# #### **62. Mineral management**
#
# Develop a class called `MineralManagement` that manages a list of minerals. This class must include the following methods:
#
# - `add_mineral`: adds a mineral to the list.
# - `remove_mineral`: removes a mineral from the list.
# - `average_hardness`: displays the average hardness of all minerals in the list.
#
# To implement these methods, you may use the `Mineral` class <span style="color:#43c6ac">developed in Exercise 60</span>.

# %%
# List of minerals
minerals = [
    # Name, hardness (Mohs)
    ("cuarzo", 7),
    ("pirita", 6),
    ("galena", 2),
    ("calcopirita", 4),
    ("talco", 1)
]

# %% [markdown]
# #### **63. Metallic deposit**
#
# Create a class called `MetallicDeposit` with attributes for `name`, `extracted_metal`, and `reserves` (in tonnes). <br>
# This class must include a method called `evaluate_deposit` that determines whether the deposit is `large` (more than 100,000 tonnes) or `small`.

# %% [markdown]
# #### **64. Deposit management system**
#
# Develop a class called `DepositSystem` that contains a list of deposits. This class must include the following methods:
#
# - `add_deposit`: adds a deposit to the list.
# - `remove_deposit`: removes a deposit from the list.
# - `show_deposits_by_metal`: displays the deposits that extract a specific metal.
# - `show_deposit_with_max_reserves`: displays the deposit with the largest amount of reserves.
#
# To implement these methods, you may consider using the `MetallicDeposit` class <span style="color:#43c6ac">developed in Exercise 63</span>.

# %%
# List of mineral deposits
deposits = [
    # Name, extracted metal, reserves
    ("Antamina", "copper", 1_000_000),
    ("Quellaveco", "gold", 500_000),
    ("Yanacocha", "gold", 2_000_000),
    ("Toromocho", "copper", 1_500_000),
    ("Escondida", "copper", 5_500_000),
    ("Cerro Verde", "copper", 3_000_000),
    ("Las Bambas", "copper", 1_200_000),
    ("Chuquicamata", "copper", 4_000_000)
]

# %% [markdown]
# <a id="part-7"></a>

# %% [markdown]
# ### <span style="color:lightgreen">**Standard Python libraries**</span>
# ***
#
# Imports are usually placed at the top of the file.
#
# It is recommended to import a specific module or function rather than importing the entire module using `from module import *`.

# %% [markdown]
# #### **65. Linear space**
#
# How would you create a Numpy array that contains 10 equally spaced values between 0 and 100?

# %%
import numpy as np

# %% [markdown]
# #### **66. Average of altitudes**
#
# If you have an array representing the altitudes of different points in a terrain, how would you calculate the mean of these altitudes using Numpy?

# %%
import numpy as np

# Altitudes at different meters above sea level
z = np.array([1000, 1100, 1050, 1500, 950, 800])

# %% [markdown]
# #### **67. Mass calculation**
#
# You have an array representing the volume of different rock samples and another array representing the density of those same samples. Calculate the total mass of all the samples.

# %%
import numpy as np

# Input
volume = np.array([20, 30, 40, 70, 55]) # cm3
density = np.array([2.5, 2.7, 2.55, 2.8, 3.0]) # g/cm3

# %% [markdown]
# #### **68. Mineral densities**
#
# You are given a list of 5 common minerals and their densities. Convert this list into an array and calculate the average density of these minerals. Determine which mineral has the lowest density and which has the highest.

# %%
import numpy as np

# Input
minerals = ["quartz", "feldspar", "mica", "calcite", "halite"]
densities = np.array([2.65, 2.60, 2.76, 2.71, 2.16]) # g/cm3

# %% [markdown]
# #### **69. Average density calculation**
#
# You have a 2D array that represents density values at different points in a geological block. If each row of the array represents different depths and each column represents different horizontal locations, how would you use Numpy to obtain the average density at the third depth?

# %%
import numpy as np

# 2D array of densities
density = np.array([[2.50, 2.60, 2.55, 2.70],
                    [2.20, 2.25, 2.55, 2.40],
                    [2.40, 2.50, 2.75, 3.50],
                    [2.70, 2.80, 2.75, 3.10]])

# %% [markdown]
# #### **70. Correlation coefficient**
#
# You have two arrays representing seismic measurements at two different subsurface points. Both arrays have the same shape. How would you use Numpy to calculate the point-by-point correlation between these two sets of measurements?

# %%
import numpy as np

# Input
array1 = np.array([0.10, 0.20, 0.70, 0.45, 0.15, 0.40, 0.38, 0.22])
array2 = np.array([0.15, 0.20, 0.75, 0.40, 0.20, 0.40, 0.37, 0.16])

# %% [markdown]
# #### **71. Average porosity**
#
# Ten samples of sedimentary rocks were taken to a laboratory, and the following data were obtained:
#
# | Total Volume (cm$^{3}$) | Pore Volume (cm$^{3}$) |
# | --- | --- |
# | 103 | 395 |
# | 121 | 451 |
# | 109 | 402 |
# |  94 | 377 |
# |  86 | 358 |
# | 106 | 398 |
# | 112 | 411 |
# | 151 | 586 |
# | 143 | 529 |
# | 188 | 713 |
#
# The formula for porosity in a sedimentary rock is as follows:
#
# <center>
#     $ \Large porosity = \frac{V_{pores}}{V_{total}} \times 100\% $
# </center>
# <br>
#
# Using this information, write a script that calculates the average porosity (%) of the 10 samples.

# %%
import numpy as np

# %% [markdown]
# #### **72. Sediment Analysis**
#
# Create an array containing 1000 measurements of grain size (particle diameters) of a sediment, with values ranging between 0.0625 mm (fine sand) and 2 mm (coarse sand). Calculate the average particle diameter. Determine what percentage of the measurements belong to fine sand (<0.5 mm).

# %%
import numpy as np

# %% [markdown]
# #### **73. Seismic Mapping**
#
# You are given a 3D array that represents seismic velocities in a subsurface volume. Generate a 2D array that represents the average velocity at each depth.
# > The structure of the 3D array is as follows: `(z, y, x)` where `x` and `y` are the horizontal dimensions and `z` is the vertical dimension.

# %%
import numpy as np

# 3D volume array (3 x 3 x 3)
seismic = np.array([
    # First layer of low velocity
    [[4.5, 4.7, 4.6],
     [4.3, 4.5, 4.6],
     [4.5, 4.4, 4.8]
    ],
    # Second layer of intermediate velocity
    [[5.2, 5.3, 5.1],
     [5.4, 5.2, 5.0],
     [5.3, 5.1, 5.4]
    ],
    # Third layer of high velocity
    [[5.8, 5.9, 5.8],
     [5.8, 6.0, 6.1],
     [5.9, 5.9, 6.0]
    ]
])

# %% [markdown]
# #### **74. Mineral Distribution**
#
# You are given three 3D arrays that represent the concentrations (%) of three minerals in a rock volume. Find which layer has the highest average of the sum of all minerals.

# %%
import numpy as np

# 3D volume of chalcopyrite (%)
chalcopyrite = np.array([
    # First layer
    [[8.1, 8.0, 6.6],
     [5.3, 8.5, 5.2],
     [7.1, 6.5, 7.2]
    ],
    # Second layer
    [[6.2, 8.3, 5.1],
     [7.4, 7.2, 6.0],
     [6.3, 8.1, 7.4]
    ],
    # Third layer
    [[7.8, 4.9, 8.8],
     [5.8, 6.0, 4.1],
     [8.9, 5.9, 7.0]
    ]
])

# 3D volume of chalcocite (%)
chalcocite = np.array([
    # Primera capa
    [[4.1, 5.0, 5.6],
     [3.3, 5.5, 6.2],
     [5.1, 6.5, 5.2]
    ],
    # Segunda capa
    [[4.2, 5.3, 4.1],
     [3.4, 5.2, 4.0],
     [6.3, 4.1, 6.4]
    ],
    # Tercera capa
    [[4.8, 5.9, 6.8],
     [5.8, 4.0, 3.1],
     [5.9, 4.9, 4.0]
    ]
])

# 3D volume of bornite (%)
bornite = np.array([
    # Primera capa
    [[4.1, 4.0, 7.6],
     [3.3, 6.5, 6.2],
     [3.1, 5.5, 4.2]
    ],
    # Segunda capa
    [[4.2, 6.3, 5.1],
     [4.4, 6.2, 8.0],
     [5.3, 6.1, 7.4]
    ],
    # Tercera capa
    [[3.8, 4.9, 5.8],
     [4.8, 5.0, 5.1],
     [3.9, 3.9, 6.0]
    ]
])

# Dictionary with 3D arrays
minerals = {
    "Chalcopyrite": chalcopyrite,
    "Chalcocite": chalcocite,
    "Bornite": bornite
}

# %% [markdown]
# #### **75. Groundwater flow**
#
# Using the following 3D array that represents subsurface permeability, determine the total volume of the aquifer, measured by the number of blocks in the array that have a permeability above the threshold value of 6.

# %%
import numpy as np

# Random number generator
rng = np.random.default_rng()

# Create an array with random permeability values
permeability = rng.uniform(low=1, high=10, size=(3, 3, 3))

# Show the 3D volume
print("3D Volume - Permeability")
print("-----------------------------")
print(permeability)
print("")

# %% [markdown]
# #### **76. Gravimetric anomaly analysis (Part 1)**
#
# You have a 2D array of size 100x100 representing gravimetric measurements in a geological study area (measured in Gal, where the Earth’s average gravity is 981 Gal). The measurements vary with the density of the underlying rocks. Using Numpy, perform the following steps:
# - Process the array to identify areas where gravimetric anomalies exceed two standard deviations above the dataset’s mean value.
# - Calculate the total area (in terms of array cells) that these anomalous zones represent.
#
# This analysis will help identify regions with rock densities significantly different from the mean, indicating possible interesting geological structures.

# %%
import numpy as np

# Random number generator
rng = np.random.default_rng()

# 2D array with random gravimetry values (Gal)
mean_value = 981   # Population mean
variation = 5      # Population standard deviation
gravimetry = mean_value + (variation * rng.normal(size=(100, 100)) * np.linspace(0, 1, 100))

# %% [markdown]
# #### **77. Maximum concentration**
#
# Represent a rock volume using a 3D array with the following characteristics:
#
# - It must have dimensions of 3 x 3 x 3 cells, where each dimension of the array corresponds to length, width, and depth.
# - The array should contain Au concentrations (g/t) with values ranging between 0.1 and 5.0.
#
# Using this array, how would you determine the location (indices) of the point with the maximum concentration of this mineral in the volume?

# %%
import numpy as np

# Random number generator
rng = np.random.default_rng()

# %% [markdown]
# #### **78. Apparent dip in a slope**
#
# A rock stratum exposed on a road slope has an azimuth of 150° and an apparent dip of 33°. Calculate the true dip of the stratum considering that the azimuth of the road slope is 180°. Use the following formula:
#
# <center>
#     $ \Large \phi_{real} = \arctan \left( \frac{\tan(\phi_{apparent})}{\cos(\beta)} \right)$
# </center>
#
# Where:
#
# - $\phi_{real}$ : true dip
# - $\phi_{apparent}$ : apparent dip
# - $\beta$ : angle between the stratum azimuth and the slope azimuth

# %%
import numpy as np

# %% [markdown]
# #### **79. Beach erosion**
#
# Generate a 1D array that represents the elevation of a beach at 100 different points, where the minimum elevation is 0 and the maximum is 8 meters. Also, identify how many points have an elevation below 5 meters.

# %%
import numpy as np

# Random number generator
rng = np.random.default_rng()

# %% [markdown]
# #### **80. Subsurface temperatures**
#
# You are given two 1D arrays representing the temperatures and depths recorded in a geothermal well. Determine at what depth the maximum temperature of the well is found.

# %%
import numpy as np

# 1D arrays with temperatures (in °C) and depths (in meters)
temperature = np.array([412, 421, 400, 405, 413, 416, 424, 428, 421, 418, 419, 411, 415, 414, 426])
depth = np.array([10, 21, 34, 43, 49, 55, 64, 73, 81, 94, 100, 112, 125, 134])

# %% [markdown]
# #### **81. Rock layer depth**
#
# You are given a 1D array with depth measurements of a specific rock layer at different locations (for example, a series of drillholes):
# - Interpolate the missing `NaN` values using the mean of the non-empty values.
# - Determine the maximum variation (difference) between two consecutive measurements.

# %%
import numpy as np

# 1D array of rock layer depth
depth = np.array([100, 105, 110, np.nan, 112, 113, np.nan, np.nan, 120, 116, np.nan, 107]) # meters

# %% [markdown]
# #### **82. Gravity anomaly analysis (Part 1)**
#
# You are given a 2D array representing gravimetric measurements on a grid over a study area. Identify and list the coordinates of the three highest measurements.

# %%
import numpy as np

# 2D array of gravimetric measurements
gravimetry = np.array([[970, 972, 974, 968],
                       [969, 973, 975, 974],
                       [971, 975, 978, 980],
                       [975, 977, 979, 977]])

# %% [markdown]
# #### **83. Rock porosity**
#
# You are given a 2D array where each row represents a rock sample and the columns represent different porosity measurements. Compute the variance of porosity for each sample.

# %%
import numpy as np

# 2D array of porosity
porosity = np.array([
    [2.15, 2.17, 2.21, 2.28, 2.24, 2.19, 2.22, 2.25, 2.21, 2.16], # Sample 1
    [2.05, 2.07, 2.11, 2.13, 2.09, 2.10, 2.08, 2.09, 2.11, 2.10], # Sample 2
    [2.71, 2.70, 2.68, 2.65, 2.75, 2.71, 2.72, 2.69, 2.66, 2.67], # Sample 3
    [2.56, 2.55, 2.51, 2.53, 2.58, 2.59, 2.58, 2.53, 2.55, 2.56], # Sample 4
    [2.14, 2.13, 2.11, 2.09, 2.14, 2.17, 2.10, 2.09, 2.13, 2.16], # Sample 5
    [2.66, 2.65, 2.59, 2.61, 2.62, 2.58, 2.64, 2.63, 2.59, 2.60]  # Sample 6
])

# %% [markdown]
# #### **84. Seismic data interpolation**
#
# You have a 2D array with seismic data for a specific area. Some values are `NaN`, indicating that there is no data at that location. <br>
# Replace the `NaN` values with the average of the surrounding values (consider using a 3×3 window around the missing value).

# %%
import numpy as np

# 2D array of seismic data
seismic = np.array([
    [0.91, 0.85, 0.83, 0.84, 0.80, 0.78, 0.82, 0.88, 0.92, 0.94],
    [0.87, np.nan, 0.81, 0.80, 0.79, 0.81, 0.83, 0.84, 0.85, 0.90],
    [0.86, 0.81, 0.79, np.nan, 0.78, 0.75, 0.73, np.nan, 0.82, 0.88],
    [0.81, 0.80, 0.78, 0.82, 0.79, 0.76, 0.74, 0.78, 0.83, 0.89],
    [0.78, 0.77, 0.75, 0.79, 0.78, np.nan, 0.78, 0.81, 0.82, 0.84],
    [0.75, np.nan, 0.70, 0.73, 0.76, 0.79, 0.82, np.nan, 0.80, 0.81],
    [0.77, 0.75, 0.73, np.nan, 0.80, 0.82, 0.84, 0.88, 0.81, 0.78],
    [0.79, 0.76, 0.78, 0.80, 0.78, 0.76, 0.77, 0.82, 0.78, 0.76],
    [0.82, 0.79, np.nan, 0.81, 0.83, 0.85, 0.88, 0.91, np.nan, 0.80],
    [0.84, 0.81, 0.79, 0.84, 0.89, 0.93, 0.95, 0.88, 0.82, 0.84],
])

# %% [markdown]
# #### **85. 2D stratigraphic model (Part 1)**
#
# Implement a stratigraphic model in NumPy according to the following criteria:
# - The model has three layers of different materials: conglomerate, sandstone, and limestone.
# - Each layer has an extent of 6×6 cells.
# - Each rock-layer cell is assigned a variable thickness value (meters).
# - The limestone layer has a variable thickness between 8 and 18 meters.
# - The sandstone layer has a variable thickness between 10 and 16 meters.
# - The conglomerate layer is at the top of the model and can be computed by subtracting the thickness of the other two layers from the total thickness.
# - The total thickness (including all three layers) must be equal to 50 meters.
#
# > It is recommended to use a uniform random distribution (`np.random.uniform` or `rng.uniform`) to generate the thickness values.

# %%
import numpy as np

# Random number generator
rng = np.random.default_rng()

# %% [markdown]
# #### **86. 2D stratigraphic model (Part 2)**
#
# Using the stratigraphic model <span style="color:#43c6ac">developed in Exercise 85</span>, calculate the average thickness of each layer across the entire model.

# %%
import numpy as np

# Random number generator
rng = np.random.default_rng()

# %% [markdown]
# #### **87. 2D stratigraphic model (Part 3)**
#
# Using the stratigraphic model <span style="color:#43c6ac">developed in Exercise 85</span>, identify what percentage of the area has a conglomerate thickness greater than the combined thickness of limestone and sandstone.

# %%
import numpy as np

# Random number generator
rng = np.random.default_rng()

# %% [markdown]
# #### **88. Aquifer volume estimation**
#
# You are given a 2D array (20×20) where each cell represents the thickness (in meters) of an aquifer at different locations within a region of interest.
# Determine the total volume of the aquifer (in cubic meters), assuming that each cell in the array has a side length of 25 meters.

# %%
import numpy as np

# Random number generator
rng = np.random.default_rng()

# 2D thickness array
thickness = rng.uniform(low=0, high=10, size=(20, 20)) + np.abs(rng.normal(size=(20, 20)))

# %% [markdown]
# #### **89. Displaying information with `pandas`**
#
# Using the following DataFrame, randomly select 10 rows from the DataFrame and calculate the mean SiO₂ value of those rows.

# %%
import pandas as pd

# Input
data = pd.read_csv("files/rocks.csv")
data.head()

# %% [markdown]
# #### **90. Creating columns in `pandas`**
#
# Using the following DataFrame, create a column called `FeOT + MgO` that sums the values from the `FeOT` and `Mg` columns.

# %%
import pandas as pd

# Input
data = pd.read_csv("files/rocks.csv")
data.head()

# %% [markdown]
# #### **91. Descriptive statistics**
#
# Using the following DataFrame, calculate the descriptive statistical measures (mean, median, standard deviation, etc.) for the numerical columns.

# %%
import pandas as pd

# Input
data = pd.read_csv("files/rocks.csv")
data.head()

# %% [markdown]
# #### **92. Data manipulation**
#
# How could you filter the following DataFrame so that it only displays rocks with a silica content (column `SiO2`) greater than or equal to 60%?

# %%
import pandas as pd

# Input
data = pd.read_csv("files/rocks.csv")
data.head()

# %% [markdown]
# #### **93. Relative concentration**
#
# How could you manipulate the following DataFrame so that the numerical columns represent the relative concentration of each element with respect to the total?

# %%
import pandas as pd

# Input
data = pd.read_csv("files/rocks.csv")
data.head()

# %% [markdown]
# #### **94. Bivariate analysis**
#
# How could you create a correlation plot to evaluate the relationships between the different numerical columns in the following DataFrame?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Input
data = pd.read_csv("files/rocks.csv")
data.head()

# %% [markdown]
# #### **95. Data visualization**
#
# Using the following DataFrame, how could you visualize the distribution of these concentrations for a specific rock using histograms?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Input
data = pd.read_csv("files/rocks.csv")
data.head()

# %% [markdown]
# #### **96. Rock classification**
#
# Using the following DataFrame, classify the samples according to the following criteria:
# - **Ultramafic**: less than 45% silica.
# - **Mafic**: between 45% and 55% silica.
# - **Intermediate**: between 55% and 65% silica.
# - **Felsic**: more than 65% silica.
#
# Store the classification result in a new column called `igneous`.
# > It is recommended to use the `apply` method on the DataFrame.

# %%
import pandas as pd

# Input
data = pd.read_csv("files/rocks.csv")
data.head()

# %% [markdown]
# #### **97. Automated data report**
#
# Using the following DataFrame, develop a function called `report` that performs the following tasks:
# - Extract 100 random samples from the DataFrame.
# - Print the mean values of `SiO2` and `Al2O3` for the selected samples.
# - Print the number of samples for each rock type.
# - Display a scatter plot of `SiO2` vs. `Al2O3`, colored according to rock type.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Input
data = pd.read_csv("files/rocks.csv")
data.head()

# %% [markdown]
# #### **98. Gravity anomaly visualization (Part 2)**
#
# Using Matplotlib, graphically represent the identified zones on the original gravity measurement map <span style="color:#4ac6ac">developed in Exercise 88</span>.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Random number generator
rng = np.random.default_rng()

# 2D array with random gravimetric values (Gal)
mean = 981    # Average
variance = 5  # Standard deviation
gravimetrics = mean + (variance * rng.normal(size=(100, 100)) * np.linspace(0, 1, 100))

# %% [markdown]
# #### **99. 2D stratigraphic model (Part 4)**
#
# Using Matplotlib and NumPy, extract a stratigraphic section (one row of the 2D array) from the model <span style="color:#43c6ac">developed in Exercise 85</span> and graphically represent the changes in the layers.
#
# > Visualize the figure considering that each cell in the 2D array has a side length of 20 meters. <br>
# > The `fill_between` function from Matplotlib is very useful for visualizing stratigraphic layers in section.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Random number generator
rng = np.random.default_rng()

# %% [markdown]
# #### **100. Terrestrial geothermal gradient model (Part 2)**
#
# Based on the `temperature` function <span style="color:#43c6ac">developed in Exercise 51</span>, implement a function with the same name that returns the temperature value in °C.
# Using this function, generate a Matplotlib plot showing the variation of **Depth vs. Temperature** over the range from 0 to 6,360 km.
#
# > **Note:** You may use NumPy’s `linspace` function to generate a linear range of depth values.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ---
